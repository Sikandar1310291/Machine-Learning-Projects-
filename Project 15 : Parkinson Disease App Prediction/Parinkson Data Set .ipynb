# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# %%
data = pd.read_csv(r"C:\Users\ma516\OneDrive\Desktop\Machine Learning Projects\Parinkson Prediction App\parkinsons.data")
data.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
data.shape
# Out:
# (195, 24)

# %%
data.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
x  = data.drop(columns=["status" , "name"])
y = data["status"]

# %%
pd.set_option('display.max_columns', None)
x.tail()
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 190      174.188       230.978        94.261         0.00459
# 191      209.516       253.017        89.488         0.00564
# 192      174.688       240.005        74.287         0.01360
# 193      198.764       396.961        74.904         0.00740
# 194      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 190           0.00003   0.00263   0.00259     0.00790       0.04087
# 191           0.00003   0.00331   0.00292     0.00994       0.02751
# 192           0.00008   0.00624   0.00564     0.01873       0.02308
# 193           0.00004   0.00370   0.00390     0.01109       0.02296
# 194           0.00003   0.00295   0.00317     0.00885       0.01884
#
#      MDVP:Shimmer(dB)  Shimmer:APQ3  Shimmer:APQ5  MDVP:APQ  Shimmer:DDA  \
# 190             0.405       0.02336       0.02498   0.02745      0.07008
# ...

# %%
y.tail()
# Out:
# 190    0
# 191    0
# 192    0
# 193    0
# 194    0
# Name: status, dtype: int64

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=2,test_size=0.2)

# %%
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (156, 22) (39, 22) (156,) (39,)

# %%
model = SVC(kernel="linear")

# %%
model.fit(x_train , y_train )
# Out:
# SVC(kernel='linear')

# %%
trained_data =  model.predict(x_train)
accuracy_score_of_trained_data = accuracy_score(trained_data , y_train)
print("accuracy_score_of_trained_data :" , accuracy_score_of_trained_data)
# Out:
# accuracy_score_of_trained_data : 0.8717948717948718

# %%
tested_data =  model.predict(x_test)
accuracy_score_of_tested_data = accuracy_score(tested_data , y_test)
print("accuracy_score_of_tested_data :" , accuracy_score_of_tested_data)
# Out:
# accuracy_score_of_tested_data : 0.8717948717948718

# %%
print(model.score(x_train,y_train))
print(model.score(x_test,y_test))
# Out:
# 0.8717948717948718
# 0.8717948717948718

# %%
input_data = (198.764	,396.961	,74.904,	0.00740,	0.00004,	0.00370	,0.00390,	0.01109	,0.02296	,0.241,	0.01265,	0.01321	,0.01588,	0.03794,	0.07223,	19.020,	0.451221,	0.643956	,-6.744577,	0.207454	,2.138608,	0.123306)
arrayed_data = np.asarray(input_data)
reshaped_data = arrayed_data.reshape(1,-1)
prediction = model.predict(reshaped_data)
print(prediction)

if(prediction == 0):
    print("The person Does not have  parkinson disease ")
else:
    print("The person have  parkinson disease ")
# Out:
# [0]
# The person Does not have  parkinson disease
# C:\Users\ma516\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
import pickle

# %%
pickle.dump(model , open("Parkinson1.sav" , "wb"))

# %%
loaded_model = pickle.load(open("Parkinson1.sav" , "rb"))

# %%
input_data = (214.289	,260.277	,77.973	,0.00567	,0.00003	,0.00295,	0.00317	,0.00885	,0.01884	,0.190	,0.01026,	0.01161	,0.01373,	0.03078,	0.04398	,21.209,	0.462803,	0.664357	,-5.724056,	0.190667,	2.555477,	0.148569)
arrayed_data = np.asarray(input_data)
reshaped_data = arrayed_data.reshape(1,-1)
prediction = loaded_model.predict(reshaped_data)
print(prediction)

if(prediction == 0):
    print("The person Does not have  parkinson disease ")
else:
    print("The person have  parkinson disease ")
# Out:
# [1]
# The person have  parkinson disease
# C:\Users\ma516\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
